# %% [markdown]
# <a href="https://colab.research.google.com/github/mounika6776/Alarm-manager-with-Notification/blob/master/Day3_Verification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot 2026-05-21 144847.png](data:image/png;base64,...)
