# %% [markdown]
# <a href="https://colab.research.google.com/github/mounika6776/Alarm-manager-with-Notification/blob/master/Day2_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day2_SixPatterns_YourName
# ________________________________________
# Pattern 1 — PERSONA
# Prompt
# You are a senior placement coach at Aditya University. You have prepared 200 B.Tech CSE students for TCS, Infosys, and Cognizant placement interviews.
#
# A 3rd-year CSE student with 7.5 CGPA asks you about Big-O notation.
#
# Explain it the way you would in a 1-on-1 prep session — concrete, conversational, exam-relevant.
# AI Output
# [Paste AI response here]
# Self Score
# 4/5
# Peer Score
# 8/10
# ________________________________________
# Pattern 2 — FEW-SHOT
# Prompt
# Here are example explanations from a placement coach:
#
# Q: What is recursion?
# A: A function calling itself with a smaller problem. Like Russian dolls — open one, find a smaller one inside. Stops at base case. Example: factorial.
#
# Q: What is a stack?
# A: LIFO data structure. Push to add, pop to remove. Like a stack of plates — you take from the top.
#
# Q: What is Big-O notation?
# A:
# AI Output
# [Paste AI response here]
# Self Score
# 4/5
# Peer Score
# 8/10
# ________________________________________
# Pattern 3 — CHAIN-OF-THOUGHT
# Prompt
# Explain Big-O notation to a placement interview candidate.
#
# Think step by step before answering.
#
# Step 1: define Big-O in one sentence.
# Step 2: give one concrete example with code.
# Step 3: explain why interviewers ask about it.
# Step 4: synthesise into a 3-sentence summary.
# AI Output
# [Paste AI response here]
# Self Score
# 4/5
# Peer Score
# 8/10
# ________________________________________
# Pattern 4 — STRUCTURED OUTPUT
# Prompt
# Explain Big-O notation for a placement interview.
#
# Return ONLY valid JSON with this exact shape — no markdown fences, no commentary:
#
# {
#   "definition": "one-sentence definition",
#   "intuition": "concrete analogy",
#   "code_example": "Python snippet showing O(n) and O(n²)",
#   "common_pitfall": "what students get wrong",
#   "interview_test_question": "a follow-up question an interviewer might ask"
# }
# AI Output
# [Paste AI response here]
# Self Score
# 4/5
# Peer Score
# 8/10
# ________________________________________
# Pattern 5 — SYSTEM PROMPT
# System Prompt
# You are a senior placement coach for B.Tech CSE students at an Indian engineering college.
#
# You prepare students for TCS / Infosys / Cognizant interviews.
#
# You explain technical concepts in 50-80 words max, conversationally, with one concrete code example.
# User Prompt
# Explain Big-O notation.
# AI Output
# [Paste AI response here]
# Self Score
# 4/5
# Peer Score
# 8/10
# ________________________________________
# Pattern 6 — PROMPT CHAINING
# Conversation 1 — Extract
# Prompt
# List the 5 most important sub-concepts a B.Tech student must understand about Big-O notation.
#
# Just the list, no explanation.
# Output
# [Paste AI response here]
# ________________________________________
# Conversation 2 — Expand
# Prompt
# For each of these 5 sub-concepts of Big-O notation, write a 1-paragraph explanation tailored to a 3rd-year B.Tech CSE student preparing for placement interviews:
#
# [paste the 5 points]
# Output
# [Paste AI response here]
# ________________________________________
# Conversation 3 — Polish
# Prompt
# Synthesise these 5 paragraphs into ONE concise 80-word interview-prep explanation of Big-O notation.
#
# Preserve all 5 sub-concepts.
#
# Conversational tone.
#
# End with one practice question.
#
# [paste the 5 paragraphs]
# Output
# [Paste AI response here]
# Self Score
# 5/5
# Peer Score
# 9/10
# ________________________________________
# Reflection
# For my placement-prep students, the patterns I will use most are Persona and Prompt Chaining because they produce clearer, interview-focused explanations and help students understand complex topics step by step.
