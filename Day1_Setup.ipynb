# %% [markdown]
# <a href="https://colab.research.google.com/github/mounika6776/Alarm-manager-with-Notification/blob/master/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines a progression of AI competency, from basic understanding to strategic leadership:
#
# *   **Layer 1: AI Literacy & Tool Usage:** Understanding AI fundamentals, ethical implications, and practical proficiency in using existing AI tools (e.g., ChatGPT, Midjourney).
# *   **Layer 2: AI Application & Customization:** Skills in integrating AI solutions into workflows, customizing existing AI models, and building simple AI-powered features using APIs.
# *   **Layer 3: AI Development & Research:** Deep technical expertise in training machine learning models, developing new algorithms, and contributing to AI research and engineering.
# *   **Layer 4: AI Strategy & Leadership:** Defining AI vision, governance, ethical frameworks, managing AI projects, and driving organizational transformation through AI.
